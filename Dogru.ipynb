# %%
library(rvest)
library(httr)

get_wiki_covid19_page <- function() {
    
  # Our target COVID-19 wiki page URL is: https://en.wikipedia.org/w/index.php?title=Template:COVID-19_testing_by_country  
  # Which has two parts: 
    # 1) base URL `https://en.wikipedia.org/w/index.php  
    # 2) URL parameter: `title=Template:COVID-19_testing_by_country`, seperated by question mark ?
    
  # Wiki page base
  wiki_base_url <- "https://en.wikipedia.org/w/index.php"
  # You will need to create a List which has an element called `title` to specify which page you want to get from Wiki
  # in our case, it will be `Template:COVID-19_testing_by_country`
  query_params <- list(title = "Template:COVID-19_testing_by_country")
  # - Use the `GET` function in httr library with a `url` argument and a `query` argument to get a HTTP response
  response <- GET(wiki_base_url, query = query_params)
  # Use the `return` function to return the response
  return(response)
}


# Call the get_wiki_covid19_page function and print the response
get_wiki_covid19_page()

# Get the root html node from the http response in task 1 
root_node <- read_html(get_wiki_covid19_page())
root_node

# Get the table node from the root html node
table_node <- html_nodes(root_node, "table")
table_node

# Read the table node and convert it into a data frame, and print the data frame for review
covid_df <- as.data.frame(html_table(table_node))
covid_df

# Print the summary of the data frame
cov_19 <- summary(covid_df)
cov_19
# Out:
# Loading required package: xml2
# Response [https://en.wikipedia.org/w/index.php?title=Template%3ACOVID-19_testing_by_country]
#   Date: 2023-04-17 18:58
#   Status: 200
#   Content-Type: text/html; charset=UTF-8
#   Size: 432 kB
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-fea...
# <head>
# <meta charset="UTF-8"/>
# <title>Template:COVID-19 testing by country - Wikipedia</title>
# <script>document.documentElement.className="client-js vector-feature-language...
# "3f05d6ba-5960-4851-ab28-6318f0af23b2","wgCSPNonce":false,"wgCanonicalNamespa...
# "CS1 uses Khmer-language script (km)","CS1 Khmer-language sources (km)","CS1 ...
# "CS1 Mongolian-language sources (mn)","CS1 foreign language sources (ISO 639-...
# "levels":1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"lt...
# ...
# {html_document}
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" lang="en" dir="ltr">
# [1] <head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8 ...
# [2] <body class="skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr ...
# {xml_nodeset (4)}
# [1] <table class="box-Update plainlinks ombox ombox-content ambox-Update" rol ...
# [2] <table class="wikitable plainrowheaders sortable collapsible autocollapse ...
# [3] <table class="plainlinks ombox mbox-small ombox-notice" role="presentatio ...
# [4] <table class="wikitable mw-templatedata-doc-params">\n<caption>\n<span cl ...
#     X1
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 144 NA
# 145 NA
# 146 NA
# 147 NA
# 148 NA
# 149 NA
# 150 NA
# 151 NA
# 152 NA
# 153 NA
# 154 NA
# 155 NA
# 156 NA
# 157 NA
# 158 NA
# 159 NA
# 160 NA
# 161 NA
# 162 NA
# 163 NA
# 164 NA
# 165 NA
# 166 NA
# 167 NA
# 168 NA
# 169 NA
# 170 NA
# 171 NA
# 172 NA
# 173 NA
#     X2
# 1   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 2   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 3   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 4   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 5   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 6   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 7   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 8   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 9   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 10  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 11  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 12  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 13  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 14  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 15  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 16  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 17  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 18  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 19  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 20  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 21  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 22  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 23  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 24  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 25  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 26  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 27  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 28  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 29  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 30  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# ⋮   ⋮
# 144 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 145 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 146 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 147 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 148 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 149 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 150 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 151 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 152 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 153 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 154 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 155 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 156 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 157 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 158 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 159 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 160 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 161 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 162 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 163 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 164 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 165 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 166 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 167 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 168 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 169 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 170 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 171 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 172 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 173 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
#     Country.or.region
# 1   Afghanistan
# 2   Albania
# 3   Algeria
# 4   Andorra
# 5   Angola
# 6   Antigua and Barbuda
# 7   Argentina
# 8   Armenia
# 9   Australia
# 10  Austria
# 11  Azerbaijan
# 12  Bahamas
# 13  Bahrain
# 14  Bangladesh
# 15  Barbados
# 16  Belarus
# 17  Belgium
# 18  Belize
# 19  Benin
# 20  Bhutan
# 21  Bolivia
# 22  Bosnia and Herzegovina
# ...
# 171 [191]
# 172 [3][192]
# 173 .mw-parser-output .reflist{font-size:90%;margin-bottom:0.5em;list-style-type:decimal}.mw-parser-output .reflist .references{font-size:100%;margin-bottom:0;list-style-type:inherit}.mw-parser-output .reflist-columns-2{column-width:30em}.mw-parser-output .reflist-columns-3{column-width:25em}.mw-parser-output .reflist-columns{margin-top:0.3em}.mw-parser-output .reflist-columns ol{margin-top:0}.mw-parser-output .reflist-columns li{page-break-inside:avoid;break-inside:avoid-column}.mw-parser-output .reflist-upper-alpha{list-style-type:upper-alpha}.mw-parser-output .reflist-upper-roman{list-style-type:upper-roman}.mw-parser-output .reflist-lower-alpha{list-style-type:lower-alpha}.mw-parser-output .reflist-lower-greek{list-style-type:lower-greek}.mw-parser-output .reflist-lower-roman{list-style-type:lower-roman}\n^ Local time.\n\n^ For some countries it is unclear whether they report samples or cases. One person tested twice is recorded as one case and two samples.\n\n^ Excluding Taiwan.\n\n^ Excluding Northern Cyprus.\n\n^ Excluding Greenland and the Faroe Islands.\n\n^ Excluding Overseas France.\n\n^ Testing data from 4 May to 12 May is missing because of the transition to the new reporting system SI-DEP.\n\n^ Excluding Abkhazia and South Ossetia.\n\n^ Data for residents only.\n\n^ Excluding Transnistria.\n\n^ Northern Cyprus is not recognized as a sovereign state by any country except Turkey.\n\n^ Includes data for Liechtenstein.\n\n^ Not a United Nations member.
#     X1.1
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 144 NA
# 145 NA
# 146 NA
# 147 NA
# 148 NA
# 149 NA
# 150 NA
# 151 NA
# 152 NA
# 153 NA
# 154 NA
# 155 NA
# 156 NA
# 157 NA
# 158 NA
# 159 NA
# 160 NA
# 161 NA
# 162 NA
# 163 NA
# 164 NA
# 165 NA
# 166 NA
# 167 NA
# 168 NA
# 169 NA
# 170 NA
# 171 NA
# 172 NA
# 173 NA
#     X2.1
# 1   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 2   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 3   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 4   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 5   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 6   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 7   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 8   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 9   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 10  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 11  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 12  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 13  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 14  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 15  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 16  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 17  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 18  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 19  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 20  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 21  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 22  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 23  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 24  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 25  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 26  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 27  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 28  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 29  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 30  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# ⋮   ⋮
# 144 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 145 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 146 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 147 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 148 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 149 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 150 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 151 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 152 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 153 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 154 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 155 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 156 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 157 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 158 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 159 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 160 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 161 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 162 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 163 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 164 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 165 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 166 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 167 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 168 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 169 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 170 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 171 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 172 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 173 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
#     Parameter Parameter.1 Description    Type    Status
# 1   state     state       no description Unknown optional
# 2   state     state       no description Unknown optional
# 3   state     state       no description Unknown optional
# 4   state     state       no description Unknown optional
# 5   state     state       no description Unknown optional
# 6   state     state       no description Unknown optional
# 7   state     state       no description Unknown optional
# 8   state     state       no description Unknown optional
# 9   state     state       no description Unknown optional
# 10  state     state       no description Unknown optional
# 11  state     state       no description Unknown optional
# 12  state     state       no description Unknown optional
# 13  state     state       no description Unknown optional
# 14  state     state       no description Unknown optional
# 15  state     state       no description Unknown optional
# 16  state     state       no description Unknown optional
# 17  state     state       no description Unknown optional
# 18  state     state       no description Unknown optional
# 19  state     state       no description Unknown optional
# 20  state     state       no description Unknown optional
# 21  state     state       no description Unknown optional
# 22  state     state       no description Unknown optional
# 23  state     state       no description Unknown optional
# 24  state     state       no description Unknown optional
# 25  state     state       no description Unknown optional
# 26  state     state       no description Unknown optional
# 27  state     state       no description Unknown optional
# 28  state     state       no description Unknown optional
# 29  state     state       no description Unknown optional
# 30  state     state       no description Unknown optional
# ⋮   ⋮         ⋮           ⋮              ⋮       ⋮
# 144 state     state       no description Unknown optional
# 145 state     state       no description Unknown optional
# 146 state     state       no description Unknown optional
# 147 state     state       no description Unknown optional
# 148 state     state       no description Unknown optional
# 149 state     state       no description Unknown optional
# 150 state     state       no description Unknown optional
# 151 state     state       no description Unknown optional
# 152 state     state       no description Unknown optional
# 153 state     state       no description Unknown optional
# 154 state     state       no description Unknown optional
# 155 state     state       no description Unknown optional
# 156 state     state       no description Unknown optional
# 157 state     state       no description Unknown optional
# 158 state     state       no description Unknown optional
# 159 state     state       no description Unknown optional
# 160 state     state       no description Unknown optional
# 161 state     state       no description Unknown optional
# 162 state     state       no description Unknown optional
# 163 state     state       no description Unknown optional
# 164 state     state       no description Unknown optional
# 165 state     state       no description Unknown optional
# 166 state     state       no description Unknown optional
# 167 state     state       no description Unknown optional
# 168 state     state       no description Unknown optional
# 169 state     state       no description Unknown optional
# 170 state     state       no description Unknown optional
# 171 state     state       no description Unknown optional
# 172 state     state       no description Unknown optional
# 173 state     state       no description Unknown optional
#     X1               X2            Country.or.region    Date.a.
#  Mode:logical   Length:173         Length:173         Length:173
#  NA's:173       Class :character   Class :character   Class :character
#                 Mode  :character   Mode  :character   Mode  :character
#     Tested            Units.b.         Confirmed.cases.   Confirmed..tested..
#  Length:173         Length:173         Length:173         Length:173
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#  Tested..population.. Confirmed..population..     Ref.             X1.1
#  Length:173           Length:173              Length:173         Mode:logical
#  Class :character     Class :character        Class :character   NA's:173
#  Mode  :character     Mode  :character        Mode  :character
#      X2.1            Parameter         Parameter.1        Description
#  Length:173         Length:173         Length:173         Length:173
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#      Type              Status
#  Length:173         Length:173
#  Class :character   Class :character
#  Mode  :character   Mode  :character

# %%
preprocess_covid_data_frame <- function(data_frame) {
    
    shape <- dim(data_frame)

    # Remove the World row
    data_frame<-data_frame[!(data_frame$`Country.or.region`=="World"),]
    # Remove the last row
    data_frame <- data_frame[1:172, ]
    
    # We dont need the Units and Ref columns, so can be removed
    data_frame["Ref."] <- NULL
    data_frame["Units.b."] <- NULL
    
    # Renaming the columns
    names(data_frame) <- c("country", "date", "tested", "confirmed", "confirmed.tested.ratio", "tested.population.ratio", "confirmed.population.ratio")
    
    # Convert column data types
    data_frame$country <- as.factor(data_frame$country)
    data_frame$date <- as.factor(data_frame$date)
    data_frame$tested <- as.numeric(gsub(",","",data_frame$tested))
    data_frame$confirmed <- as.numeric(gsub(",","",data_frame$confirmed))
    data_frame$'confirmed.tested.ratio' <- as.numeric(gsub(",","",data_frame$`confirmed.tested.ratio`))
    data_frame$'tested.population.ratio' <- as.numeric(gsub(",","",data_frame$`tested.population.ratio`))
    data_frame$'confirmed.population.ratio' <- as.numeric(gsub(",","",data_frame$`confirmed.population.ratio`))
    
    return(data_frame)
}

df <- preprocess_covid_data_frame(covid_df)
df
# Out:
# Warning message in preprocess_covid_data_frame(covid_df):
# “NAs introduced by coercion”Warning message in preprocess_covid_data_frame(covid_df):
# “NAs introduced by coercion”
#     country
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 143 NA
# 144 NA
# 145 NA
# 146 NA
# 147 NA
# 148 NA
# 149 NA
# 150 NA
# 151 NA
# 152 NA
# 153 NA
# 154 NA
# 155 NA
# 156 NA
# 157 NA
# 158 NA
# 159 NA
# 160 NA
# 161 NA
# 162 NA
# 163 NA
# 164 NA
# 165 NA
# 166 NA
# 167 NA
# 168 NA
# 169 NA
# 170 NA
# 171 NA
# 172 NA
#     date
# 1   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 2   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 3   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 4   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 5   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 6   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 7   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 8   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 9   This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 10  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 11  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 12  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 13  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 14  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 15  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 16  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 17  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 18  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 19  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 20  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 21  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 22  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 23  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 24  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 25  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 26  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 27  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 28  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 29  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 30  This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# ⋮   ⋮
# 143 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 144 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 145 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 146 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 147 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 148 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 149 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 150 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 151 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 152 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 153 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 154 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 155 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 156 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 157 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 158 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 159 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 160 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 161 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 162 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 163 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 164 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 165 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 166 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 167 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 168 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 169 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 170 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 171 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
# 172 This template needs to be updated.  Please help update this template to reflect recent events or newly available information. Relevant discussion may be found on  the talk page.
#     tested confirmed confirmed.tested.ratio tested.population.ratio
# 1   NA     NA           154767                 49621
# 2   NA     NA           428654                 96838
# 3   NA     NA           230553                 58574
# 4   NA     NA           300307                 37958
# 5   NA     NA           399228                 20981
# 6   NA     NA            15268                   832
# 7   NA     NA         35716069               9060495
# 8   NA     NA          3099602                422963
# 9   NA     NA         78548492              10112229
# 10  NA     NA        205817752               5789991
# 11  NA     NA          6838458                792638
# 12  NA     NA           259366                 37483
# 13  NA     NA         10578766                696614
# 14  NA     NA          7417714               1151644
# 15  NA     NA           770100                103014
# 16  NA     NA         13217569                982809
# 17  NA     NA         36548544               4691499
# 18  NA     NA           572900                 60694
# 19  NA     NA           595112                  7884
# 20  NA     NA          1736168                 12702
# 21  NA     NA          4358669                910228
# 22  NA     NA          1872934                399887
# 23  NA     NA          2026898                232432
# 24  NA     NA         23561497              10081676
# 25  NA     NA           153804                   338
# 26  NA     NA         10993239               1295524
# 27  NA     NA           158777                 12123
# 28  NA     NA            90019                   884
# 29  NA     NA          1812706                 77914
# 30  NA     NA           942685                 32681
# ⋮   ⋮      ⋮         ⋮                      ⋮
# 143 NA     NA         12185475               2473599
# 144 NA     NA         16206203                 65315
# 145 NA     NA          7391882               1861034
# 146 NA     NA          2826117               1322282
# 147 NA     NA         11378282               1637848
# 148 NA     NA          6592010                 90029
# 149 NA     NA           164472                 10688
# 150 NA     NA         54128524               3821305
# 151 NA     NA          2384745                 93128
# 152 NA     NA           158804                 23316
# 153 NA     NA          9996795               1074751
# 154 NA     NA         23283909               4276836
# 155 NA     NA         30275725               8622129
# 156 NA     NA             3880                   509
# 157 NA     NA          1579597                 26162
# 158 NA     NA           807269                 39358
# 159 NA     NA           512730                 92997
# 160 NA     NA          2893625                703732
# 161 NA     NA         61236294               5435831
# 162 NA     NA           852444                 39979
# 163 NA     NA         15648456               3367461
# 164 NA     NA        198685717               1049537
# 165 NA     NA        522526476              22232377
# 166 NA     NA        929349291              90749469
# 167 NA     NA          6089116                895592
# 168 NA     NA          2630000                 43975
# 169 NA     NA          3179074                159149
# 170 NA     NA         45772571              11403302
# 171 NA     NA          3301860                314850
# 172 NA     NA          2529087                257893
#     confirmed.population.ratio <NA>   <NA>    <NA>
# 1   32.10                      0.40   0.13    NA
# 2   22.60                      15.0   3.4     NA
# 3   25.40                      0.53   0.13    NA
# 4   12.60                      387    49.0    NA
# 5    5.30                      1.3    0.067   NA
# 6    5.40                      15.9   0.86    NA
# 7   25.40                      78.3   20.0    NA
# 8   13.60                      105    14.3    NA
# 9   12.90                      313    40.3    NA
# 10   2.80                      2,312  65.0    NA
# 11  11.60                      69.1   8.0     NA
# 12  14.50                      67.3   9.7     NA
# 13   6.60                      674    44.4    NA
# 14  15.50                      4.5    0.70    NA
# 15  13.40                      268    35.9    NA
# 16   7.40                      139    10.4    NA
# 17  12.80                      317    40.7    NA
# 18  10.60                      140    14.9    NA
# 19   1.30                      5.1    0.067   NA
# 20   0.73                      234    1.71    NA
# 21  20.90                      38.1   8.0     NA
# 22  21.40                      54.7   11.7    NA
# 23  11.50                      89.9   10.3    NA
# 24  42.80                      11.2   4.8     NA
# 25   0.22                      33.5   0.074   NA
# 26  11.80                      158    18.6    NA
# 27   7.60                      0.76   0.058   NA
# 28   0.98                      0.76   0.0074  NA
# 29   4.30                      11.2   0.48    NA
# 30   3.50                      3.6    0.12    NA
# ⋮   ⋮                          ⋮      ⋮       ⋮
# 143 20.30                      175    35.5    NA
# 144  0.40                      284    1.1     NA
# 145 25.20                      135    34.1    NA
# 146 46.80                      135    63.1    NA
# 147 14.40                      19.2   2.8     NA
# 148  1.40                      12.7   0.17    NA
# 149  6.50                      1.3    0.084   NA
# 150  7.10                      116    8.2     NA
# 151  3.90                      10.9   0.43    NA
# 152 14.70                      0.36   0.053   NA
# 153 10.80                      96.8   10.4    NA
# 154 18.40                      270    49.7    NA
# 155 28.48                      128.3  36.528  NA
# 156 13.10                      0.0065 0.00085 NA
# 157  1.70                      2.3    0.038   NA
# 158  4.90                      9.4    0.46    NA
# 159 18.10                      37.6   6.8     NA
# 160 24.30                      24.5   6.0     NA
# 161  8.90                      73.6   6.5     NA
# 162  4.70                      1.9    0.087   NA
# 163 21.50                      37.2   8.0     NA
# 164  0.53                      2,070  10.9    NA
# 165  4.30                      774    32.9    NA
# 166  9.80                      281    27.4    NA
# 167 14.70                      175    25.8    NA
# 168  1.70                      7.7    0.13    NA
# 169  5.00                      11.0   0.55    NA
# 170 24.90                      46.4   11.6    NA
# 171  9.50                      19.0   1.8     NA
# 172 10.20                      17.0   1.7     NA
#     <NA>
# 1   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 2   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 3   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 4   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 5   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 6   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 7   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 8   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 9   This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 10  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 11  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 12  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 13  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 14  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 15  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 16  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 17  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 18  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 19  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 20  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 21  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 22  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 23  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 24  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 25  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 26  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 27  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 28  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 29  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 30  This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# ⋮   ⋮
# 143 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 144 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 145 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 146 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 147 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 148 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 149 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 150 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 151 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 152 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 153 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 154 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 155 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 156 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 157 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 158 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 159 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 160 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 161 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 162 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 163 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 164 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 165 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 166 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 167 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 168 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 169 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 170 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 171 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
# 172 This template uses TemplateStyles:\nTemplate:COVID-19 testing by country/styles.css
#     <NA>  <NA>  <NA>           <NA>    <NA>
# 1   state state no description Unknown optional
# 2   state state no description Unknown optional
# 3   state state no description Unknown optional
# 4   state state no description Unknown optional
# 5   state state no description Unknown optional
# 6   state state no description Unknown optional
# 7   state state no description Unknown optional
# 8   state state no description Unknown optional
# 9   state state no description Unknown optional
# 10  state state no description Unknown optional
# 11  state state no description Unknown optional
# 12  state state no description Unknown optional
# 13  state state no description Unknown optional
# 14  state state no description Unknown optional
# 15  state state no description Unknown optional
# 16  state state no description Unknown optional
# 17  state state no description Unknown optional
# 18  state state no description Unknown optional
# 19  state state no description Unknown optional
# 20  state state no description Unknown optional
# 21  state state no description Unknown optional
# 22  state state no description Unknown optional
# 23  state state no description Unknown optional
# 24  state state no description Unknown optional
# 25  state state no description Unknown optional
# 26  state state no description Unknown optional
# 27  state state no description Unknown optional
# 28  state state no description Unknown optional
# 29  state state no description Unknown optional
# 30  state state no description Unknown optional
# ⋮   ⋮     ⋮     ⋮              ⋮       ⋮
# 143 state state no description Unknown optional
# 144 state state no description Unknown optional
# 145 state state no description Unknown optional
# 146 state state no description Unknown optional
# 147 state state no description Unknown optional
# 148 state state no description Unknown optional
# 149 state state no description Unknown optional
# 150 state state no description Unknown optional
# 151 state state no description Unknown optional
# 152 state state no description Unknown optional
# 153 state state no description Unknown optional
# 154 state state no description Unknown optional
# 155 state state no description Unknown optional
# 156 state state no description Unknown optional
# 157 state state no description Unknown optional
# 158 state state no description Unknown optional
# 159 state state no description Unknown optional
# 160 state state no description Unknown optional
# 161 state state no description Unknown optional
# 162 state state no description Unknown optional
# 163 state state no description Unknown optional
# 164 state state no description Unknown optional
# 165 state state no description Unknown optional
# 166 state state no description Unknown optional
# 167 state state no description Unknown optional
# 168 state state no description Unknown optional
# 169 state state no description Unknown optional
# 170 state state no description Unknown optional
# 171 state state no description Unknown optional
# 172 state state no description Unknown optional
